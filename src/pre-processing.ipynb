# %%
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.impute import SimpleImputer
import numpy as np
import pandas as pd

# %% [markdown]
# Load Dataset

# %%
df = pd.read_csv('../data/US_Accidents_March23_sample.csv')
df.head(10)
# Out:
#           ID   Source  Severity                     Start_Time  \
# 0   A-227993  Source2         2            2016-05-18 16:28:12
# 1  A-5584682  Source1         2            2021-10-17 00:25:30
# 2   A-309630  Source2         2            2016-11-13 16:55:24
# 3  A-3580182  Source1         2            2017-03-15 09:21:23
# 4  A-6523880  Source1         2            2021-02-12 04:27:00
# 5  A-7100647  Source1         2            2020-06-19 16:26:01
# 6  A-4190196  Source1         2            2022-02-22 09:02:46
# 7  A-5962252  Source1         2  2021-08-28 21:19:00.000000000
# 8  A-4658270  Source1         2            2022-06-19 10:50:00
# 9  A-2099924  Source2         2            2019-05-13 06:15:11
#
#                         End_Time  Start_Lat   Start_Lng    End_Lat  \
# 0            2016-05-18 16:58:12  39.815620  -82.822304        NaN
# 1            2021-10-17 00:52:30  35.110082  -80.975220  35.107982
# 2            2016-11-13 17:40:24  47.234718 -122.487633        NaN
# 3            2017-03-15 15:21:23  43.176570  -71.611080  43.177915
# 4            2021-02-12 08:44:00  41.944932  -83.555199  41.945482
# 5            2020-06-19 16:55:16  43.613860 -116.262640  43.613860
# 6            2022-02-22 11:34:23  25.732933  -80.340203  25.733035
# 7  2021-08-28 23:32:17.000000000  32.786155  -96.812695  32.783963
# 8            2022-06-19 12:08:23  41.157002  -76.797775  41.175349
# 9            2019-05-13 07:47:15  34.054260 -118.237823        NaN
#
#       End_Lng  Distance(mi)  ... Roundabout Station   Stop Traffic_Calming  \
# 0         NaN         0.000  ...      False   False  False           False
# 1  -80.978715         0.245  ...      False   False  False           False
# 2         NaN         0.010  ...      False   False  False           False
# 3  -71.624505         0.683  ...      False   False  False           False
# 4  -83.559469         0.223  ...      False   False  False           False
# 5 -116.262640         0.000  ...      False   False  False           False
# 6  -80.335226         0.310  ...      False    True  False           False
# 7  -96.813574         0.160  ...      False   False  False           False
# 8  -76.791129         1.314  ...      False   False  False           False
# 9         NaN         0.000  ...      False   False  False           False
#
#   Traffic_Signal Turning_Loop Sunrise_Sunset Civil_Twilight Nautical_Twilight  \
# 0          False        False            Day            Day               Day
# 1          False        False          Night          Night             Night
# 2          False        False          Night            Day               Day
# 3          False        False            Day            Day               Day
# 4          False        False          Night          Night             Night
# 5          False        False            Day            Day               Day
# 6          False        False            Day            Day               Day
# 7          False        False          Night          Night             Night
# 8          False        False            Day            Day               Day
# 9           True        False            Day            Day               Day
#
#   Astronomical_Twilight
# 0                   Day
# 1                 Night
# 2                   Day
# 3                   Day
# 4                 Night
# 5                   Day
# 6                   Day
# 7                   Day
# 8                   Day
# 9                   Day
#
# [10 rows x 46 columns]

# %% [markdown]
# Handle Missing Values

# %%
num_imputer = SimpleImputer(strategy='mean')
cat_imputer = SimpleImputer(strategy='most_frequent')

# %%
num_cols = ['Start_Lat', 'Start_Lng', 'End_Lat', 'End_Lng', 'Distance(mi)']
cat_cols = ['Sunrise_Sunset', 'Civil_Twilight', 'Nautical_Twilight', 'Astronomical_Twilight']

# %%
df[num_cols] = num_imputer.fit_transform(df[num_cols])
df[cat_cols] = cat_imputer.fit_transform(df[cat_cols])

# %% [markdown]
# Feature Encoding

# %%
encoder = OneHotEncoder(sparse_output=False)
encoded_columns = encoder.fit_transform(df[cat_cols])
encoded_df = pd.DataFrame(encoded_columns, columns=encoder.get_feature_names_out(cat_cols))
df = df.drop(cat_cols, axis=1)
df = pd.concat([df, encoded_df], axis=1)

# %% [markdown]
# Normalization of Numerical Data

# %%
scaler = StandardScaler()
df[num_cols] = scaler.fit_transform(df[num_cols])

# %% [markdown]
# Feature Engineering

# %%
df['Start_Time'] = df['Start_Time'].str.replace(r'\.\d+', '', regex=True)
df['Start_Time'] = pd.to_datetime(df['Start_Time'])
df['Month'] = df['Start_Time'].dt.month
df['Year'] = df['Start_Time'].dt.year

# %% [markdown]
# Removing outliers using IQR

# %%
Q1 = df[num_cols].quantile(0.25)
Q3 = df[num_cols].quantile(0.75)
IQR = Q3 - Q1
df = df[~((df[num_cols] < (Q1 - 1.5 * IQR)) | (df[num_cols] > (Q3 + 1.5 * IQR))).any(axis=1)]

# %%
df.head(10)
# Out:
#            ID   Source  Severity          Start_Time  \
# 0    A-227993  Source2         2 2016-05-18 16:28:12
# 1   A-5584682  Source1         2 2021-10-17 00:25:30
# 2    A-309630  Source2         2 2016-11-13 16:55:24
# 3   A-3580182  Source1         2 2017-03-15 09:21:23
# 4   A-6523880  Source1         2 2021-02-12 04:27:00
# 5   A-7100647  Source1         2 2020-06-19 16:26:01
# 6   A-4190196  Source1         2 2022-02-22 09:02:46
# 7   A-5962252  Source1         2 2021-08-28 21:19:00
# 9   A-2099924  Source2         2 2019-05-13 06:15:11
# 10  A-4170357  Source1         2 2022-11-11 13:04:18
#
#                          End_Time  Start_Lat   Start_Lng    End_Lat  \
# 0             2016-05-18 16:58:12  39.815620  -82.822304        NaN
# 1             2021-10-17 00:52:30  35.110082  -80.975220  35.107982
# 2             2016-11-13 17:40:24  47.234718 -122.487633        NaN
# 3             2017-03-15 15:21:23  43.176570  -71.611080  43.177915
# 4             2021-02-12 08:44:00  41.944932  -83.555199  41.945482
# 5             2020-06-19 16:55:16  43.613860 -116.262640  43.613860
# 6             2022-02-22 11:34:23  25.732933  -80.340203  25.733035
# 7   2021-08-28 23:32:17.000000000  32.786155  -96.812695  32.783963
# 9             2019-05-13 07:47:15  34.054260 -118.237823        NaN
# 10            2022-11-11 13:24:51  40.563274  -74.323283  40.556774
#
#        End_Lng  Distance(mi)  ...   Stop Traffic_Calming Traffic_Signal  \
# 0          NaN         0.000  ...  False           False          False
# 1   -80.978715         0.245  ...  False           False          False
# 2          NaN         0.010  ...  False           False          False
# 3   -71.624505         0.683  ...  False           False          False
# 4   -83.559469         0.223  ...  False           False          False
# 5  -116.262640         0.000  ...  False           False          False
# 6   -80.335226         0.310  ...  False           False          False
# 7   -96.813574         0.160  ...  False           False          False
# 9          NaN         0.000  ...  False           False           True
# 10  -74.319617         0.489  ...  False           False          False
#
#    Turning_Loop Sunrise_Sunset Civil_Twilight Nautical_Twilight  \
# 0         False            Day            Day               Day
# 1         False          Night          Night             Night
# 2         False          Night            Day               Day
# 3         False            Day            Day               Day
# 4         False          Night          Night             Night
# 5         False            Day            Day               Day
# 6         False            Day            Day               Day
# 7         False          Night          Night             Night
# 9         False            Day            Day               Day
# 10        False            Day            Day               Day
#
#    Astronomical_Twilight Month  Year
# 0                    Day     5  2016
# 1                  Night    10  2021
# 2                    Day    11  2016
# 3                    Day     3  2017
# 4                  Night     2  2021
# 5                    Day     6  2020
# 6                    Day     2  2022
# 7                    Day     8  2021
# 9                    Day     5  2019
# 10                   Day    11  2022
#
# [10 rows x 48 columns]
